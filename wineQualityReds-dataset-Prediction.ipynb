# %%
'Unnamed: 0', 'fixed.acidity', 'volatile.acidity', 'citric.acid',
       'residual.sugar', 'chlorides', 'free.sulfur.dioxide',
       'total.sulfur.dioxide', 'density', 'pH', 'sulphates', 'alcohol',
       'quality'

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
df = pd.read_csv('wineQualityReds.csv')

# %% [markdown]
# Initial analysis of Red and White wines.
# Features:
# Fixed Acidity - measure of the total concentration of titratable acids and free hydrogen ions.
# Volatile Acidity - measure of the total concentration of ‘volatile acids’ in wine.
# Citric Acid - one of three primary acids found in grapes and converted by the winemaking process.
# Residual Sugars - natural grape sugars that are leftover after fermentation ceases.
# Chlorides - The amount of chlorides in a wine is usually an indicator of its saltiness.
# Sulphur Dioxide levels - Sulphur dioxide (SO2) is used as an antioxidant and preservative and has become widely used in winemaking
# Density - measure of the alcohol concentration in wines.
# pH - (power of hydrogen) - measure of the hydrogen ion concentration in the solution.
# Sulphates - Salts of sulfuric acid in wine.
# Alcohol

# %%
df.head()
# Out:
#    Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# 0           1            7.4              0.70         0.00             1.9
# 1           2            7.8              0.88         0.00             2.6
# 2           3            7.8              0.76         0.04             2.3
# 3           4           11.2              0.28         0.56             1.9
# 4           5            7.4              0.70         0.00             1.9
#
#    chlorides  free.sulfur.dioxide  total.sulfur.dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# ...

# %%
# summary of data 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            1599 non-null   int64
#  1   fixed.acidity         1599 non-null   float64
#  2   volatile.acidity      1599 non-null   float64
#  3   citric.acid           1599 non-null   float64
#  4   residual.sugar        1599 non-null   float64
#  5   chlorides             1599 non-null   float64
#  6   free.sulfur.dioxide   1599 non-null   float64
#  7   total.sulfur.dioxide  1599 non-null   float64
#  8   density               1599 non-null   float64
#  9   pH                    1599 non-null   float64
#  10  sulphates             1599 non-null   float64
#  11  alcohol               1599 non-null   float64
#  12  quality               1599 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 162.5 KB

# %%
#discriptive summary 
df.describe()
# Out:
#         Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  \
# count  1599.000000    1599.000000       1599.000000  1599.000000
# mean    800.000000       8.319637          0.527821     0.270976
# std     461.735855       1.741096          0.179060     0.194801
# min       1.000000       4.600000          0.120000     0.000000
# 25%     400.500000       7.100000          0.390000     0.090000
# 50%     800.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1599.000000      15.900000          1.580000     1.000000
#
#        residual.sugar    chlorides  free.sulfur.dioxide  total.sulfur.dioxide  \
# count     1599.000000  1599.000000          1599.000000           1599.000000
# mean         2.538806     0.087467            15.874922             46.467792
# std          1.409928     0.047065            10.460157             32.895324
# ...

# %%
# shapwe of data 
df.shape
# Out:
# (1599, 13)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'fixed.acidity', 'volatile.acidity', 'citric.acid',
#        'residual.sugar', 'chlorides', 'free.sulfur.dioxide',
#        'total.sulfur.dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
# conclution - imbalence data set 
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# Data Cleaning

# %%
## Missing values 
df.isnull().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1594    False
# 1595    False
# 1596    False
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %%
# to chweck duplicate
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, fixed.acidity, volatile.acidity, citric.acid, residual.sugar, chlorides, free.sulfur.dioxide, total.sulfur.dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1599, 13)

# %%
df.corr()
# Out:
#                       Unnamed: 0  fixed.acidity  volatile.acidity  \
# Unnamed: 0              1.000000      -0.268484         -0.008815
# fixed.acidity          -0.268484       1.000000         -0.256131
# volatile.acidity       -0.008815      -0.256131          1.000000
# citric.acid            -0.153551       0.671703         -0.552496
# residual.sugar         -0.031261       0.114777          0.001918
# chlorides              -0.119869       0.093705          0.061298
# free.sulfur.dioxide     0.090480      -0.153794         -0.010504
# total.sulfur.dioxide   -0.117850      -0.113181          0.076470
# density                -0.368372       0.668047          0.022026
# pH                      0.136005      -0.682978          0.234937
# sulphates              -0.125307       0.183006         -0.260987
# alcohol                 0.245123      -0.061668         -0.202288
# quality                 0.066453       0.124052         -0.390558
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
df.quality.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
sns.histplot(df['fixed.acidity'],kde=True)
# Out:
# <AxesSubplot: xlabel='fixed.acidity', ylabel='Count'>

# %%
for i in df.columns:
    sns.histplot(df[i],kde=True)

# %%
# categorical plot
sns.catplot(x='quality',y='alcohol',data=df,kind='box')

# %%
df.iloc[[122]]
# Out:
#      Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# 122         123            7.3             0.695          0.0             2.5
#
#      chlorides  free.sulfur.dioxide  total.sulfur.dioxide  density    pH  \
# 122      0.075                  3.0                  13.0    0.998  3.49
#
#      sulphates  alcohol  quality
# 122       0.52      9.2        5

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'fixed.acidity', 'volatile.acidity', 'citric.acid',
#        'residual.sugar', 'chlorides', 'free.sulfur.dioxide',
#        'total.sulfur.dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
# fix spaces in columns names
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Unnamed: 0', 'fixed.acidity', 'volatile.acidity', 'citric.acid',
#        'residual.sugar', 'chlorides', 'free.sulfur.dioxide',
#        'total.sulfur.dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  \
# 0              1            7.4             0.700         0.00
# 1              2            7.8             0.880         0.00
# 2              3            7.8             0.760         0.04
# 3              4           11.2             0.280         0.56
# 4              5            7.4             0.700         0.00
# ...          ...            ...               ...          ...
# 1594        1595            6.2             0.600         0.08
# 1595        1596            5.9             0.550         0.10
# 1596        1597            6.3             0.510         0.13
# 1597        1598            5.9             0.645         0.12
# 1598        1599            6.0             0.310         0.47
#
#       residual.sugar  chlorides  free.sulfur.dioxide  total.sulfur.dioxide  \
# 0                1.9      0.076                 11.0                  34.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'fixed.acidity', 'volatile.acidity', 'citric.acid',
#        'residual.sugar', 'chlorides', 'free.sulfur.dioxide',
#        'total.sulfur.dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'fixed.acidity', 'volatile.acidity', 'citric.acid',
#        'residual.sugar', 'chlorides', 'free.sulfur.dioxide',
#        'total.sulfur.dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            1599 non-null   int64
#  1   fixed.acidity         1599 non-null   float64
#  2   volatile.acidity      1599 non-null   float64
#  3   citric.acid           1599 non-null   float64
#  4   residual.sugar        1599 non-null   float64
#  5   chlorides             1599 non-null   float64
#  6   free.sulfur.dioxide   1599 non-null   float64
#  7   total.sulfur.dioxide  1599 non-null   float64
#  8   density               1599 non-null   float64
#  9   pH                    1599 non-null   float64
#  10  sulphates             1599 non-null   float64
#  11  alcohol               1599 non-null   float64
#  12  quality               1599 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 174.9 KB

# %%
changing the other columns to flot data datatype
# Out:
#   Cell In[126], line 1
#     changing the other columns to flot data datatype
#              ^
# SyntaxError: invalid syntax

# %%
objects = [features for features in df.columns if df[features].dtypes=='O']

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  \
# 0              1            7.4             0.700         0.00
# 1              2            7.8             0.880         0.00
# 2              3            7.8             0.760         0.04
# 3              4           11.2             0.280         0.56
# 4              5            7.4             0.700         0.00
# ...          ...            ...               ...          ...
# 1594        1595            6.2             0.600         0.08
# 1595        1596            5.9             0.550         0.10
# 1596        1597            6.3             0.510         0.13
# 1597        1598            5.9             0.645         0.12
# 1598        1599            6.0             0.310         0.47
#
#       residual.sugar  chlorides  free.sulfur.dioxide  total.sulfur.dioxide  \
# 0                1.9      0.076                 11.0                  34.0
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  \
# count  1599.000000    1599.000000       1599.000000  1599.000000
# mean    800.000000       8.319637          0.527821     0.270976
# std     461.735855       1.741096          0.179060     0.194801
# min       1.000000       4.600000          0.120000     0.000000
# 25%     400.500000       7.100000          0.390000     0.090000
# 50%     800.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1599.000000      15.900000          1.580000     1.000000
#
#        residual.sugar    chlorides  free.sulfur.dioxide  total.sulfur.dioxide  \
# count     1599.000000  1599.000000          1599.000000           1599.000000
# mean         2.538806     0.087467            15.874922             46.467792
# std          1.409928     0.047065            10.460157             32.895324
# ...

# %%
## Plot desnity plot for all features
plt.style.use('seaborn')
df.hist(bins=50,figsize=(20,15))
plt.show()
# Out:
# /tmp/ipykernel_278/2171285287.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
## Percentage for Pie Chart
percentage=df['quality'].value_counts(normalize=True)*100

# %%
# plotting piechart
classlabels=["quality","Not Fire"]
plt.figure(figsize=(12,7))
plt.pie(percentage,autopct='%1.1f%%')
plt.title("Pie Chart of quality")
plt.show()

# %%
# correlation 
df.corr()
# Out:
#                       Unnamed: 0  fixed.acidity  volatile.acidity  \
# Unnamed: 0              1.000000      -0.268484         -0.008815
# fixed.acidity          -0.268484       1.000000         -0.256131
# volatile.acidity       -0.008815      -0.256131          1.000000
# citric.acid            -0.153551       0.671703         -0.552496
# residual.sugar         -0.031261       0.114777          0.001918
# chlorides              -0.119869       0.093705          0.061298
# free.sulfur.dioxide     0.090480      -0.153794         -0.010504
# total.sulfur.dioxide   -0.117850      -0.113181          0.076470
# density                -0.368372       0.668047          0.022026
# pH                      0.136005      -0.682978          0.234937
# sulphates              -0.125307       0.183006         -0.260987
# alcohol                 0.245123      -0.061668         -0.202288
# quality                 0.066453       0.124052         -0.390558
#
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
## Box Plots
sns.boxplot(df['quality'],color='green')
# Out:
# <AxesSubplot: >

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[154], line 1
# ----> 1 df.drop(x)
#
# NameError: name 'x' is not defined
